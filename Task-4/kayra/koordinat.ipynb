# %%
import cv2
import numpy as np

# park alanı boy
car_spot_width = 106
car_spot_height = 46
video_yolu = 'C:/Users/TAS KAFA/Downloads/carPark.mp4'

# global değişkenler
selected_carSpot = []
is_video_playing = False

def mouse_click_events(event, x, y, flags, params):
    if event == cv2.EVENT_LBUTTONDOWN:
        selected_carSpot.append((x, y))
        print(f"Seçilen Park Yeri İşaretlendi: ({x}, {y})")

def main():
    global is_video_playing
    
    cap = cv2.VideoCapture(video_yolu)
    if not cap.isOpened():
        print("ERROR! Video Dosyası Açılmadı.")
        return
    
    ret, frame = cap.read()
    if not ret:
        print("ERROR! İstenilen Kare Alınmadı.")
        return
    
    window_name = "Park Alanları İşaretleme"
    cv2.namedWindow(window_name)
    cv2.setMouseCallback(window_name, mouse_click_events)
    
    print("Kontroller:")
    print("- Park alanı işaretlemek için fare sol tuş")
    print("- Video oynatmak/durdurmak için SPACE tuşu")
    print("- Çıkmak için 'q' tuşu")
    
    current_frame = frame.copy()
    
    while True:
        frame_to_show = current_frame.copy()
        
        # işaretlenmiş
        for (x, y) in selected_carSpot:
            cv2.rectangle(frame_to_show, (x, y),(x + car_spot_width, y + car_spot_height), (0, 255, 0), 2)
        
        # güncel
        cv2.imshow(window_name, frame_to_show)
        
        # tuş
        key = cv2.waitKey(1) & 0xFF
        if key == ord('q'):
            break
        elif key == ord(' '):  # Space tuşu
            is_video_playing = not is_video_playing
            print("Video: " + ("Oynatılıyor" if is_video_playing else "Duraklatıldı"))
            
        # durdur başlat
        if is_video_playing:
            ret, frame = cap.read()
            if ret:
                current_frame = frame.copy()
            else:
                # Video bittiğinde başa sar
                cap.set(cv2.CAP_PROP_POS_FRAMES, 0)
                ret, frame = cap.read()
                if ret:
                    current_frame = frame.copy()
                    is_video_playing = False
                    print("Video başa sarıldı ve duraklatıldı")
    
    
    print("\nİşaretlenen park yerleri koordinatları:")
    print(selected_carSpot)
    
    # kapatma
    cap.release()
    cv2.destroyAllWindows()

if __name__ == "__main__":
    main()
# Out:
# Kontroller:
# - Park alanı işaretlemek için fare sol tuş
# - Video oynatmak/durdurmak için SPACE tuşu
# - Çıkmak için 'q' tuşu
# Seçilen Park Yeri İşaretlendi: (33, 88)
# Seçilen Park Yeri İşaretlendi: (49, 152)
# Seçilen Park Yeri İşaretlendi: (56, 210)
# Seçilen Park Yeri İşaretlendi: (43, 253)
# Seçilen Park Yeri İşaretlendi: (51, 336)
# Seçilen Park Yeri İşaretlendi: (52, 411)
# Seçilen Park Yeri İşaretlendi: (53, 469)
# Seçilen Park Yeri İşaretlendi: (48, 545)
# Seçilen Park Yeri İşaretlendi: (59, 597)
# Seçilen Park Yeri İşaretlendi: (74, 631)
# Seçilen Park Yeri İşaretlendi: (146, 609)
# Seçilen Park Yeri İşaretlendi: (159, 521)
# Seçilen Park Yeri İşaretlendi: (181, 420)
# Seçilen Park Yeri İşaretlendi: (179, 343)
# Seçilen Park Yeri İşaretlendi: (172, 274)
# Seçilen Park Yeri İşaretlendi: (173, 178)
# Seçilen Park Yeri İşaretlendi: (165, 110)
# Seçilen Park Yeri İşaretlendi: (438, 83)
# Seçilen Park Yeri İşaretlendi: (411, 204)
# Seçilen Park Yeri İşaretlendi: (447, 305)
# Seçilen Park Yeri İşaretlendi: (450, 542)
# Seçilen Park Yeri İşaretlendi: (439, 607)
# Seçilen Park Yeri İşaretlendi: (416, 498)
# Seçilen Park Yeri İşaretlendi: (444, 463)
# Seçilen Park Yeri İşaretlendi: (497, 389)
# Seçilen Park Yeri İşaretlendi: (372, 248)
# Seçilen Park Yeri İşaretlendi: (556, 107)
# Seçilen Park Yeri İşaretlendi: (797, 105)
# Seçilen Park Yeri İşaretlendi: (795, 179)
# Seçilen Park Yeri İşaretlendi: (806, 240)
# Seçilen Park Yeri İşaretlendi: (800, 347)
# Seçilen Park Yeri İşaretlendi: (802, 433)
# Seçilen Park Yeri İşaretlendi: (794, 595)
# Video: Oynatılıyor
# Video: Duraklatıldı
# Video: Oynatılıyor
# Video başa sarıldı ve duraklatıldı
#
# İşaretlenen park yerleri koordinatları:
# [(33, 88), (49, 152), (56, 210), (43, 253), (51, 336), (52, 411), (53, 469), (48, 545), (59, 597), (74, 631), (146, 609), (159, 521), (181, 420), (179, 343), (172, 274), (173, 178), (165, 110), (438, 83), (411, 204), (447, 305), (450, 542), (439, 607), (416, 498), (444, 463), (497, 389), (372, 248), (556, 107), (797, 105), (795, 179), (806, 240), (800, 347), (802, 433), (794, 595)]
